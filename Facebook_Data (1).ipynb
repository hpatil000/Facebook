# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google import colab
# %cd /content/drive/My Drive/Colab Notebooks/Facebook
# Out:
# /content/drive/My Drive/Colab Notebooks/Facebook

# %%
import pandas as pd
import numpy as np

# Reading input facebook data file

inputfile=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Facebook/FacebookData.csv')

# %%
#print(inputfile.head(5))

print(inputfile.describe())

# Printing No of rows and columns in Input File

"""
print('No of Rows'+str(len(inputfile)))
print('No of Columns'+ str(len(inputfile[0])))
"""
print('%%%'*200)
# Analyze coloumn infromation
print(inputfile.info())

print('*'*200)
print('Subsetting with LINKS')
# Out:
#        Page_total_likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
#SELECT ONLY ROWS OF INPUT FILE FOR WHICH TYPE IS LINK
# CREATING SUBSETS OF DATA SET

linksubset=inputfile[inputfile['Type']=='Link']
print(linksubset.head(5))

#SELECT ONLY ROWS OF INPUT FILE FOR WHICH TYPE IS photo
print('*'*200)
photosubset=inputfile[inputfile['Type']=='Photo']
print(photosubset.head(5))


print('*'*200)
statussubset=inputfile[inputfile['Type']=='Status']
print(statussubset.head(5))


print('*'*200)
videosubset=inputfile[inputfile['Type']=='Video']
print(videosubset.head(5))

# SORTING ACCORDING TO PAGE TOTAL LIKES

input('printing sorted staus')
sortedStatus=statussubset.sort_values(['Page_total_likes'], ascending=False)
print(sortedStatus.head())

input('printing sorted Photo')
sortedPhoto=photosubset.sort_values(['Page_total_likes'], ascending=False)
print(sortedPhoto.head())

input('printing sorted Link')
sortedLink=linksubset.sort_values(['Page_total_likes'], ascending=False)
print(sortedLink.head())


input('printing sorted Video')
sortedVideo=videosubset.sort_values(['Page_total_likes'], ascending=False)
print(sortedVideo.head())

#trandf=df.transpose()
print(type(linksubset))
print(linksubset.info())
transposeLink=linksubset.transpose()
print(transposeLink.info())

transposeStatus=statussubset.transpose()
transposePhoto=photosubset.transpose()
transposeVideo=videosubset.transpose()
# Out:
#     Page_total_likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
# STEP 1 DATA TO LONG FORMAT

#Count no of columns in dataframe link
print(linksubset.dtypes.count())

#to know different coloumns of data frame link
print(linksubset.dtypes.index)

# to know datatypes of columns of link
print(linksubset.dtypes)

#format of mel function in python
#pandas.melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None)
#https://pandas.pydata.org/pandas-docs/stable/generated/pandas.melt.html
#id_vars  :  are expected columns names after melting
#value_vars : are names of columns whose value can be repeated after melting
meltedlink=pd.melt(linksubset, id_vars=['Page_total_likes', 'Type', 'Category', 'like','comment','share'])
print(meltedlink)
print(meltedlink.info())

meltedPhoto=pd.melt(photosubset, id_vars=['Page_total_likes', 'Type', 'Category', 'like','comment','share'])
print(meltedPhoto)
print(photosubset.info())


meltedvideo=pd.melt(videosubset, id_vars=['Page_total_likes', 'Type', 'Category', 'like','comment','share'])
print(meltedvideo)
print(videosubset.info())
# Out:
# 19
# Index(['Page_total_likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')
# Page_total_likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# ...

# %%
# CASTING DATA INTO WIDE FORMAT
"""
EXAMPLE OF CASGTING OF DATA INTO WIDE FORMAT
Salesman  Height   product      price
  Knut      6        bat          5
  Knut      6        ball         1
  Knut      6        wand         3
  Steve     5        pen          2
Becomes:

Salesman  Height    product_1  price_1  product_2 price_2 product_3 price_3
  Knut      6        bat          5       ball      1        wand      3
  Steve     5        pen          2        NA       NA        NA       NA


  sYNTAX : df.pivot(index='date', columns='name', values='dollars'
"""

#castedlink=meltedlink.pivot(index=['Page_total_likes', 'Type', 'Category', 'like','comment','share'], columns='variables')


#merging of dataframes

mergeddf=pd.merge(linksubset,photosubset, on='Page_total_likes')
print(mergeddf.head())

mergeddf2=pd.merge(videosubset,photosubset, on='Post Month')
print(mergeddf.head())
# Out:
#    Page_total_likes Type_x  Category_x  Post Month_x  Post Weekday_x  \
# 0            138414   Link           1            12               7
# 1            138414   Link           1            12               7
# 2            138414   Link           1            12               7
# 3            138414   Link           1            12               7
# 4            138414   Link           1            12               7
#
#    Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# 0           10     0.0                         3454
# 1           10     0.0                         3454
# 2           10     0.0                         3454
# 3           10     0.0                         3454
# 4           10     0.0                         3454
#
#    Lifetime Post Total Impressions_x  Lifetime Engaged Users_x  ...  \
# 0                               6853                       118  ...
# 1                               6853                       118  ...
# ...
